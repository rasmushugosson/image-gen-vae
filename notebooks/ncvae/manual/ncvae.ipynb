# %%
# %reload_ext autoreload

# Imports

import os
import sys
module_path = os.path.abspath(os.path.join('../image_gen_dm')) # or the path to your source code
sys.path.append(str(module_path))

import tensorflow as tf
import tf_keras as tfk
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random

tfkl = tfk.layers
tfpl = tfp.layers
tfd = tfp.distributions

TF_ENABLE_ONEDNN_OPTS=0
os.environ['TF_ENABLE_ONEDNN_OPTS'] = str(TF_ENABLE_ONEDNN_OPTS)
os.environ['TG_GPU_ALLOCATOR'] = 'cuda_malloc_async'

import image_gen_vae as igvae
import image_gen_vae.constants as consts

print('Tensorflow Version:', tf.__version__)
print("Available GPUs: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2024-04-27 21:15:20.041033: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Tensorflow Version: 2.16.1
# Available GPUs:  1
# 2024-04-27 21:15:25.001447: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.011800: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.011869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
# Constants

IMAGE_SIZE = 64
FLATTENED_SIZE = IMAGE_SIZE * IMAGE_SIZE * 3

ENCODER_HIDDEN_SIZES = [
    [256, 32],
    [1024, 64],
    [4096, 256],
    [8192, 512],
    [256, 64, 32],
    [1024, 256, 64],
    [4096, 1024, 256],
    [8192, 2048, 512],
    [256, 128, 64, 32],
    [1024, 512, 256, 64],
    [4096, 2048, 1024, 256],
    [8192, 2048, 1024, 512],
    [4096, 2048, 1024, 256, 128],
    [8192, 2048, 1024, 512, 256],
]

DECODER_HIDDEN_SIZES = [] # Construct from encoder hidden sizes in reverse

for hidden_sizes in ENCODER_HIDDEN_SIZES:
    DECODER_HIDDEN_SIZES.append(hidden_sizes[::-1])

MODEL_NAMES = []

for i in range(len(ENCODER_HIDDEN_SIZES)):
    if i < 9:
        MODEL_NAMES.append(f'ncvae0{i+1}')
    else:
        MODEL_NAMES.append(f'ncvae{i+1}')

LATENT_DIM = 2

LEARNING_RATE = 1e-4

VAL_PERCENTAGE = 0.1

# Models to run

MODEL_START = 13
MODEL_COUNT = 1

# %%
# Dataset loading

train_ds, val_ds = igvae.utils.load_datasets(val_percentage=VAL_PERCENTAGE)
# Out:
# Loading datasets...
# 2024-04-27 21:15:25.130522: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.130605: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.130633: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.284835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.284899: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.284910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2019] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-04-27 21:15:25.284946: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-27 21:15:25.284984: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3586 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Training Images:  8100
# Evaluation Images:  900
# Training Images (post-duplication):  8100
# Validation Images (post-duplication):  900

# %%
# Model class

# This code is heavily based on the Keras Team's example on Convolutional VAEs with only minor modifications.
# The original code can be found at: https://github.com/keras-team/keras-io/blob/master/examples/generative/vae.py

# Author: [fchollet](https://twitter.com/fchollet)
# Licensed under the Apache License 2.0. See LICENSE file in the root directory for more information.


class Sampling(tfkl.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

class NCVAE(tfk.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tfk.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tfk.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tfk.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            input_data, target_data = data
            z_mean, z_log_var, z = self.encoder(input_data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.losses.binary_crossentropy(target_data, reconstruction), 
                    axis=(1,2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss

        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def call(self, input_data, training=False):
        _, _, z = self.encoder(input_data)
        reconstructed_image = self.decoder(z)

        return reconstructed_image

# %%
# Encoder

models = []

for i in range(MODEL_START, MODEL_START + MODEL_COUNT):
    print(f'Model {i+1}')

    image_input = tfkl.Input(shape=consts.INPUT_SHAPE, name='image_input')

    flattened_image = tfkl.Flatten()(image_input)

    x = flattened_image
    for layer_size in ENCODER_HIDDEN_SIZES[i]:
        x = tfkl.Dense(layer_size, 
                    activation='relu',
                    kernel_initializer='glorot_uniform')(x)
        
    z_mean = tfkl.Dense(LATENT_DIM, name='z_mean', kernel_initializer='glorot_uniform')(x)
    z_log_var = tfkl.Dense(LATENT_DIM, name='z_log_var', kernel_initializer='glorot_uniform')(x)

    z = Sampling()([z_mean, z_log_var])

    encoder = tfk.Model(inputs=image_input, outputs=[z_mean, z_log_var, z], name='encoder')
    encoder.summary()

    # Decoder

    latent_inputs = tfkl.Input(shape=(LATENT_DIM,))

    y = latent_inputs
    for layer_size in DECODER_HIDDEN_SIZES[i]:
        y = tfkl.Dense(layer_size, 
                    activation='relu',
                    kernel_initializer='glorot_uniform')(y)
        
    reconstructed_flattened_image = tfkl.Dense(FLATTENED_SIZE, kernel_initializer='glorot_uniform', activation='sigmoid')(y)
    reshaped_image = tfkl.Reshape(consts.OUTPUT_SHAPE)(reconstructed_flattened_image)

    decoder = tfk.Model(inputs=latent_inputs, outputs=reshaped_image, name='decoder')
    decoder.summary()

    # Model
        
    model = NCVAE(encoder, decoder)
    model.compile(optimizer=tfk.optimizers.Adam(learning_rate=LEARNING_RATE))

    models.append(model)
# Out:
# Model 14
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image_input (InputLayer)    [(None, 64, 64, 3)]          0         []
#
#  flatten (Flatten)           (None, 12288)                0         ['image_input[0][0]']
#
#  dense (Dense)               (None, 8192)                 1006714   ['flatten[0][0]']
#                                                           88
#
#  dense_1 (Dense)             (None, 2048)                 1677926   ['dense[0][0]']
#                                                           4
#
#  dense_2 (Dense)             (None, 1024)                 2098176   ['dense_1[0][0]']
#
#  dense_3 (Dense)             (None, 512)                  524800    ['dense_2[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  131328    ['dense_3[0][0]']
#
#  z_mean (Dense)              (None, 2)                    514       ['dense_4[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    514       ['dense_4[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 120206084 (458.55 MB)
# Trainable params: 120206084 (458.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 2)]               0
#
#  dense_5 (Dense)             (None, 256)               768
#
#  dense_6 (Dense)             (None, 512)               131584
#
#  dense_7 (Dense)             (None, 1024)              525312
#
#  dense_8 (Dense)             (None, 2048)              2099200
#
#  dense_9 (Dense)             (None, 8192)              16785408
#
#  dense_10 (Dense)            (None, 12288)             100675584
#
#  reshape (Reshape)           (None, 64, 64, 3)         0
#
# =================================================================
# Total params: 120217856 (458.59 MB)
# Trainable params: 120217856 (458.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Run model

epochs = 256

i = MODEL_START
for model in models:

    history = igvae.run_model(model=model, train_ds=train_ds, val_ds=val_ds, epochs=epochs, name=MODEL_NAMES[i], plot=False)

    pd.DataFrame(history.history).to_csv(f'res/histories/{MODEL_NAMES[i]}.csv')

    igvae.val_model(model)

    i += 1
# Out:
# Epoch 1/256
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714252543.254635   28020 service.cc:145] XLA service 0x7f2c240f43f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1714252543.254722   28020 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2024-04-27 21:15:43.262615: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-27 21:15:43.282786: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8906
# I0000 00:00:1714252543.346844   28020 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 64/64 [==============================] - 24s 111ms/step - loss: 2743.4068 - reconstruction_loss: 2703.9468 - kl_loss: 5.0005 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 2/256
# 64/64 [==============================] - 3s 52ms/step - loss: 2688.0674 - reconstruction_loss: 2683.2346 - kl_loss: 3.0161 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 3/256
# 64/64 [==============================] - 3s 53ms/step - loss: 2684.0902 - reconstruction_loss: 2673.7749 - kl_loss: 4.2230 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 4/256
# 64/64 [==============================] - 3s 50ms/step - loss: 2649.7006 - reconstruction_loss: 2641.1353 - kl_loss: 4.7649 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 5/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2635.8867 - reconstruction_loss: 2628.4185 - kl_loss: 4.5466 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 6/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2623.0694 - reconstruction_loss: 2615.7529 - kl_loss: 4.5275 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 7/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2614.4434 - reconstruction_loss: 2608.1960 - kl_loss: 4.6674 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 8/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2611.2475 - reconstruction_loss: 2605.1812 - kl_loss: 4.7839 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 9/256
# 64/64 [==============================] - 3s 52ms/step - loss: 2608.8858 - reconstruction_loss: 2603.1360 - kl_loss: 4.8282 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 10/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2607.1328 - reconstruction_loss: 2601.8040 - kl_loss: 4.9127 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 11/256
# 64/64 [==============================] - 3s 50ms/step - loss: 2605.8803 - reconstruction_loss: 2600.2139 - kl_loss: 4.9877 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 12/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2604.0278 - reconstruction_loss: 2599.3147 - kl_loss: 5.0286 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 13/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2604.0081 - reconstruction_loss: 2598.2078 - kl_loss: 5.0537 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 14/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2603.0844 - reconstruction_loss: 2598.0579 - kl_loss: 5.0957 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 15/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2601.1364 - reconstruction_loss: 2596.2417 - kl_loss: 5.1042 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 16/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2600.6167 - reconstruction_loss: 2595.1489 - kl_loss: 5.2075 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 17/256
# 64/64 [==============================] - 3s 51ms/step - loss: 2600.2483 - reconstruction_loss: 2594.3779 - kl_loss: 5.2267 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 18/256
# 64/64 [==============================] - 3s 50ms/step - loss: 2599.4650 - reconstruction_loss: 2593.6135 - kl_loss: 5.2584 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 19/256
# 64/64 [==============================] - 3s 50ms/step - loss: 2598.3135 - reconstruction_loss: 2592.9739 - kl_loss: 5.3099 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 20/256
# 64/64 [==============================] - 3s 50ms/step - loss: 2597.6779 - reconstruction_loss: 2592.1116 - kl_loss: 5.3031 - val_total_loss: 0.0000e+00 - val_reconstruction_loss: 0.0000e+00 - val_kl_loss: 0.0000e+00
# Epoch 21/256
# 64/64 [==============================] - 3s 50ms/step - loss: 