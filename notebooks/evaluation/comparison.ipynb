# %%
# %reload_ext autoreload

# Imports

import os
import sys
module_path = os.path.abspath(os.path.join('../image_gen_dm')) # or the path to your source code
sys.path.append(str(module_path))

import matplotlib.pyplot as plt
import pandas as pd

TF_ENABLE_ONEDNN_OPTS=0
os.environ['TF_ENABLE_ONEDNN_OPTS'] = str(TF_ENABLE_ONEDNN_OPTS)
os.environ['TG_GPU_ALLOCATOR'] = 'cuda_malloc_async'

# %%
# Plot loss

csv_files = ['res/histories/ncvae.csv', 'res/histories/cvae.csv']

plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.ylim(2559, 2580)

df = pd.read_csv(csv_files[0])
plt.plot(df['loss'], label='NCG-VAE', color='blue')

df = pd.read_csv(csv_files[1])
plt.plot(df['loss'], label='CG-VAE', color='red')

plt.legend(loc="upper right")

plt.show()

# %%
# Plot elapsed time

csv_files = ['res/histories/ncvae.csv', 'res/histories/cvae.csv']

plt.ylabel('Loss')
plt.xlabel('Epoch')

df = pd.read_csv(csv_files[0])
plt.plot(df['elapsed_time'], label='NCG-VAE', color='blue')

df = pd.read_csv(csv_files[1])
plt.plot(df['elapsed_time'], label='CG-VAE', color='red')

plt.legend(loc="lower right")

plt.show()
